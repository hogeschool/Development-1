# %% [markdown]
# # Activities

# %% [markdown]
# Note: the practice happens almost exclusively on paper, mostly in terms of backward assignments.
#
# The backward assignments are all the predicates for the declaratively drawn figures
