# %% [markdown]
# ** All sequences of evaluations but one in the following choices contain a mistake. Choose the correct one (that is, the one without mistakes) and complete on paper two additional evaluation steps**
#
# ** Expression 1 **
#
# `eval(<while True do {x := 5}>,{})`
#
# ** Sequence 1 **
#
#  `eval(<while True do {x := 5}>,{})` $\rightarrow$ `(<if True then {x := 5; while True do {x := 5}} else {done}>,{})`
#
#  `eval(<if True then {x := 5; while True do {x := 5}} else {done}>,{})` $\rightarrow$ `(<done>,{})`
#
#  `eval (<done>,{})` $\rightarrow$ `(<done>,{})`
#
# ** Sequence 2 **
#
#  `eval(<while True do {x := 5}>,{})` $\rightarrow$ `(<if True then {x := 5} else {done}>,{})`
#
#  `eval(<if True then {x := 5} else {done}>,{})` $\rightarrow$ `(<x := 5>,{})`
#
#  `eval(<x := 5>,{})` $\rightarrow$ `(<done>,{x := 5})`
#
# ** Sequence 3 **
#
#  `eval(<while True do {x := 5}>,{})` $\rightarrow$ `(<if True then {x := 5; while True do {x := 5}} else {done}>,{})`
#
#  `eval(<if True then {x := 5; while True do {x := 5}} else {done}>,{})` $\rightarrow$ `(<x := 5; while True do {x := 5}>,{})`
#
#  `eval(<x := 5; while True do {x := 5}>,{})` $\rightarrow$ `(<done; while True do {x := 5}>,{x := 5})`
#
#
# ** Expression 2 **
#
#  `eval(<while x >= -2 do {x := x - 1}>,{x := -2})`
#
#    ** Sequence 1 **
#
#   `eval(<while x >= -2 do {x := x - 1}>,{x := -2})` $\rightarrow$ `(<if True then {x := x - 1; while x >= -2 do {x := x - 1}} else {done}>,{x := -2})`
#
#   `eval(<if True then {x := x - 1; while x >= -2 do {x := x - 1}} else {done}>,{x := -2})` $\rightarrow$ `(<x := x - 1; while x >= -2 do {x := x - 1}>,{x := -2})`
#
#   `eval(<x := x - 1; while x >= -2 do {x := x - 1}>,{x := -2})` $\rightarrow$ `(<x := -2 - 1; while x >= -2 do {x := x - 1}>,{x := -2})`
#
#   ** Sequence 2 **
#
#   `eval(<while x >= -2 do {x := x - 1}>,{x := -2})` $\rightarrow$ `(<if x >= -2 then {x := x - 1; while x >= -2 do {x := x - 1}} else {done}>,{x := -2})`
#
#   `eval(if x >= -2 then {x := x - 1; while x >= -2 do {x := x - 1}} else {done}>,{x := -2})` $\rightarrow$ `(<if -2 >= -2 then {x := x - 1; while x >= -2 do {x := x - 1}} else {done}>,{x := -2})`
#
#   `eval(<if -2 >= -2 then {x := x - 1; while x >= -2 do {x := x - 1}} else {done}>,{x := -2})` $\rightarrow$ `(<if True then {x := x - 1; while x >= -2 do {x := x - 1}} else {done}>,{x := -2})`
#
#   ** Sequence 3 **
#
#   `eval(<while x >= -2 do {x := x - 1}>,{x := -2})` $\rightarrow$ `(<x := x - 1; while x >= -2 do {x := x - 1}>,{x := -2})`
#
#   `eval(<x := x - 1; while x >= -2 do {x := x - 1}>,{x := -2})` $\rightarrow$ `(<while x >= -2 do {x := x - 1}>,{x : = -3})`
#
#   `eval(<while x >= -2 do {x := x - 1}>,{x : = -3})` $\rightarrow$ `(<x := x - 1; while x >= -2 do {x := x - 1}>,{x := -3})`
#
# ** Write down the full evaluation steps for the following program and complete the assignments in GrandeOmega **
#
# ```
# x = 2
# c = 0
# while (x > 0)
#     c = c + 1
#     x = x - 1
# ```
