# %% [markdown]
# # Activities

# %% [markdown]
# _Choose the correct evaluation result for the following expression evaluations and, on paper, write the steps of the full evaluation._
#
# - `eval_expr <3 + 2>`,$\{\}$
#     - `eval_expr<5>`
#     - 5
#     - `eval_expr<3 + 2>`
#     - `eval_expr<3>`,$\{\}$ + `eval_expr<2>`,$\{\}$
# - `eval_expr <3 + 2 * 5>,`$\{\}$
#     - `eval_expr<25>`,$\{\}$
#     - `eval_expr<3>`,$\{\}$ + `eval_expr<2 * 5>`,$\{\}$
#     - `eval_expr<3>`,$\{\}$ + `eval_expr<10>`,$\{\}$
#     - `eval_expr<13>`,$\{\}$
# - `eval_expr <(3 + 2) * 5>,`$\{\}$
#     - `eval_expr<30>`,$\{\}$
#     - `eval_expr<3 + 2>`,$\{\}$ * `eval_expr<5>`,$\{\}$
#     - `eval_expr<3>`,$\{\}$ + `eval_expr<2 * 5>`,$\{\}$
#     - `eval_expr<5>`,$\{\}$ * `eval_expr<3 + 2>`,$\{\}$
# - `eval_expr <3 * 2 + 10 / 5 - 3>,` $\{ \}$
#     - `eval_expr<3 * 2>`,$\{\}$ + `eval_expr<10 / 5 - 3>`,$\{\}$
#     - `eval_expr<6>`,$\{\}$ + `eval_expr<-1>`,$\{\}$
#     - `eval_expr<6>`,$\{\}$ + `eval_expr<10 / 5 - 3>`,$\{\}$
#     - 5
# - `eval_expr <x * 5>,`$\{ x := -1 \}$
#     - x * 5
#     - `eval_expr <x>,`$\{ x := -1 \}$ * `eval_expr <5>,`$\{ x := -1 \}$
#     - $\{ x := -1 \}$[x] *`eval_expr <5>,`$\{ x := -1 \}$
#     - $\{ x := -1 \}$[x]
# - `eval_expr <x>,`$\{ x := -1 \}$ * `eval_expr<5>,`$\{ x := -1 \}$
#     - -1 * `eval_expr<5>,`$\{ x := -1 \}$
#     - $\{ x := -1 \}$[x] * `eval_expr<5>,`$\{ x := -1 \}$
#     - -5
#     - $\{ x := -1 \}$[x] * 5
# - `eval_expr <x * y>,`$\{ x := -1, y:= 3, z := 0 \}$ + `eval_expr<z>,`$\{ x := -1, y:= 3, z := 0 \}$
#     - `eval_expr<x>,`$\{ x := -1, y:= 3, z := 0 \}$ * `eval_expr<y>`,$\{ x := -1, y:= 3, z := 0 \}$ + $\{ x := -1, y:= 3, z := 0 \}$[z]
#     - -3 + `eval_expr<y>`,$\{ x := -1, y:= 3, z := 0 \}$ + $\{ x := -1, y:= 3, z := 0 \}$[z]
#     - -3
#     - `eval_expr<x>,`$\{ x := -1, y:= 3, z := 0 \}$ * `eval_expr<y>`,$\{ x := -1, y:= 3, z := 0 \}$ + 0
#
# _Given the initial state. Write the state trace for the following programs containing variable readings and assignments_
#
# -  $\{ x := 5, y := 1 \}$
#     ``````
#     x : = 3;
#     y = x;
#     done;
#
#     ``````
# - $\{ x := 5, y := 1 \}$
#     ``````
#     z := 2;
#     x := y + 3;
#     z : = x;
#     done;
#     ``````
# - $\{ x := 5, y := 1 \}$
#     ``````
#     z := 2;
#     x := y + z;
#     z : = x - y;
#     done;
#     ``````
# - $\{ x := 5, y := 1,z := 3 \}$
#     ``````
#     z := x / 3 + y;
#     x := 3 * 5 - z;
#     y : = z * 4 + 3 / x;
#     a := z - 3;
#     done;
#     ``````
# - $\{ \}$
#     ``````
#     a = 3;
#     b = 5 * a;
#     c = (a + b) / b;
#     d = a + b - c * a;
#     done;
#     ``````
