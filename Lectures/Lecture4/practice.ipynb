# %% [markdown]
# # Activities

# %% [markdown]
# Note: the practice happens almost exclusively on paper, potentially augmented by multiple choice questions in order to submit an answer that shows understanding.
#
# Eevaluate some short programs with different inputs converted to `int`, `bool` combined with simple expressions:
#     - `first_name := input(); last_name := input(); name := first_name + " " + last_name`
#     - `age_in_months := int(input()); birth_month := int(input()); current_month := (birth_month + age_in_months) % 12`
#     - `waist_circumference := int(input()); hip_circumference := int(input()); height := int(input()); waist_hip_ratio := waist_circumference / hip_circumference; waist_height_ratio := waist_circumference / waist_height_ratio`
#     - `distance_to_HR_in_km := float(input()); time_to_HR_in_min := int(input()); avg_speed_in_kmph := 60 * distance_to_hr / time_to_hr`
#
# Evaluate various programs with multiple (nested) conditionals:
# - program 1:
# ```
# d1 := float(input())
# d2 := float(input())
# take_turn := bool(input())
# if take_turn then
#     distance := math.sqrt(d1*d1 + d2**2)
# else
#     distance := d1 + d2
# ```
#
# - program 2:
# ```
# d1 := float(input())
# d2 := float(input())
# take_turn := bool(input())
# distance := if take_turn then math.sqrt(d1*d1 + d2**2) else d1 + d2
# ```
#
# - program 3:
# ```
# name := input()
# is_human := bool(input())
# humans_are_mortal := bool(input())
# name + " is " + (if name_is_human and humans_are_mortal then "" else "possibly not ") + "mortal"
# ```
#
# - program 4:
# ```
# fitness := int(input())
# opponent_fitness := int(input())
# if opponent_fitness > fitness then
#     "You lose!!!"
# elif opponent_fitness < fitness then
#     "You are victorious!!!"
# else
#     endurance := int(input())
#     opponent_endurance := int(input())
#     if opponent_endurance > endurance then
#         "You lose!!!"
#     elif opponent_endurance < endurance then
#         "You are victorious!!!"
#     else
#         luck := bool(input())
#         if luck then "You are victorious!!!" else "You lose!!!"
# ```
#
# - program 5:
# ```
# fitness := int(input())
# opponent_fitness := int(input())
# endurance := int(input())
# opponent_endurance := int(input())
# luck := bool(input())
# lose := (opponent_fitness > fitness) or
#         ((opponent_fitness = fitness) and
#          ((opponent_endurance > endurance) or
#           ((opponent_endurance = endurance) and not luck)))
# "You " + (if lose then "lose" else "are victorious") + "!!!"
# ```
#
# - program 6:
# ```
# mammals_are_animals := bool(input())
# insects_are_animals := bool(input())
# use_faulty_reasoning := bool(input())
# mammals_are_insects :=
#     if use_faulty_reasoning then mammals_are_animals and insects_are_animals
#     else False
# if mammals_are_insects then
#     if use_faulty_reasoning then "Two wrongs do not make a right..."
#     else "Please check space weather: solar flare activity is likely exceptionally high"
# else
#     if use_faulty_reasoning then "Two wrongs do NOT NOT make a right!"
#     else "All in order!"
# ```
