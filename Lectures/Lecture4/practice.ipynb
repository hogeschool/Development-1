# %% [markdown]
# # Activities

# %% [markdown]
# **Choose the correct result for the following evaluations**
# - `eval(<if True then {x := 5} else {x := 3}>, {})`
#     - `<x := 5>, {}`
#     - `<done>, {x := 5}`
#     - `x := 3, {}`
#     - `<done>, {x := 3})`
#
# - `eval(<if x > 2 then {x := 5} else {x := 1}>, {x := 3})`
#     - `(<if 3 > 2 then {x := 5} else {x := 1}>, {x := 3})`
#     - `(<if True then {x := 5} else {x := 1}>, {x := 3})`
#     - `(<if False then {x := 5} else {x := 1}>, {x := 3})`
#     - `(<if eval_expr(<x > 2>,{x := 3}) then {x := 5} else {x := 1}, {x := 3}>)`
#
# - `eval(<if 1 > 2 then {x := 5} else {x := 1}>, {x := 3})`
#     - `(<if True then {x := 5} else {x := 1}>, {x := 3})`
#     - `(<if eval_expr(<1 > 2>,{x := 3}) then {x := 5} else {x := 1}, {x := 3}>)`
#     - `(<if False then {x := 5} else {x := 1}>, {x := 3})`
#     - `eval(<x := 1>, {x := 3})`
# - `eval(<if False then {x := 5} else {x := 1}>, {x := 3})`
#     - `<x := 5>, {x := 3}`
#     - `<x := 1>, {x := 3}`
#     - `<done>, {x := 1}`
#     - `<done>, {x := 5}`
#
# **Write the evaluation steps of the following programs using type conversions and conditional statements:**
# - **program 1**:
#     ```
#     first_name := "Sebastian"
#     last_name := "Castellanos"
#     name := first_name + " " + last_name
#     ```
# - **program 2**:
#     ```
#     age_in_months := int("180")
#     birth_month := int("9")
#     current_month := (birth_month + age_in_months) % 12
#     ```
# - **program 3**:
#     ```
#     name := "Drogon"
#     is_human := bool("False")
#     humans_are_mortal := bool("True")
#     s := "is"
#     if not(is_human and humans_are_mortal) then
#         s := " possibly not "
#     else
#         done
#     name := name + " is " + s + "mortal"
#     ```
#
# - **program 4**:
# ```
# fitness := int(35)
# opponent_fitness := int(35)
# if opponent_fitness > fitness then
#     outcome := "You lose!!!"
# elif opponent_fitness < fitness then
#     outcome := "You are victorious!!!"
# else
#     endurance := int(15)
#     opponent_endurance := int(15)
#     if opponent_endurance > endurance then
#         outcome := "You lose!!!"
#     elif opponent_endurance < endurance then
#         outcome := "You are victorious!!!"
#     else
#         luck := bool("False")
#         if luck then
#             outcome := "You are victorious!!!"
#         else
#             outcome := "You lose!!!"
# ```
#
# - **program 5**:
# ```
# fitness := int(15)
# opponent_fitness := int(22)
# endurance := int(20)
# opponent_endurance := int(4)
# luck := bool("False")
# lose := (opponent_fitness > fitness) or
#         ((opponent_fitness = fitness) and
#          ((opponent_endurance > endurance) or
#           ((opponent_endurance = endurance) and not luck)))
# if lose then
#     outcome := "lose"
# else
#     outcome := "are victorious"
# outcome := "You " + outcome + "!!!"
# ```
#
# - **program 6**:
# ```
# mammals_are_animals := bool("False")
# insects_are_animals := bool("False")
# use_faulty_reasoning := bool("False")
# statement := ""
#     if use_faulty_reasoning then
#         mammals_are_insects := mammals_are_animals and insects_are_animals
#     else
#         mammals_are_insects := False
# if mammals_are_insects then
#     if use_faulty_reasoning then
#         statement := "Two wrongs do not make a right..."
#     else
#         statement := "Please check space weather: solar flare activity is likely exceptionally high"
# else
#     if use_faulty_reasoning then
#         statement := "Two wrongs make a right!"
#     else
#         statement := "All in order!"
# ```
