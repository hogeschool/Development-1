# %% [markdown]
# # Activities

# %% [markdown]
# Note: the practice happens almost exclusively on paper, potentially augmented by multiple choice questions in order to submit an answer that shows understanding.
#
# The activities performed are:
# 1. Translate the following states into natural language
#     1. $\{ position1:= \{ x := 3, y := 0 \}, position2:= \{ x := 5, y := 1 \} \}$
#     - $\{ person1:= \{ name := \text{"Jim"}, surname := \text{"Smit"} \}, person2:= \{ name := \text{"Wim"}, surname := \text{"De Jong"} \} \}$
#     - $\{ mondayForecast:= \{ condition := \text{"Cloudy"}, minTemperature := 13, maxTemperature := 23, wind := 15, humidity := 63\% \},
#      sundayForecast:= \{ condition := \text{"Sunny"}, minTemperature := 18, maxTemperature := 26, wind := 0, humidity := 80\% \}\}$
#     - $\{ student1:= \{ name := \text{"John"}, surname := \text{"Doe"}, course := \{ code := \text{"CMIINF"}, name := \text{"Computer Science"} \}  \},
#     student2:= \{ name := \text{"Jane"}, surname := \text{"Doe"}, course := \{ code := \text{"CMITI"}, name := \text{"Computer Engineering"} \}  \} \}$
# - Modify the state representation of the `Turtle` program to include the rotation of the turtle in the state.
# - Model the following real world information
#    1. A car has a model name, a specification saying whether it is used or not, and the mileage (total distance travelled during its lifetime).
#    - A video game has a title, a producer, a PEGI (https://en.wikipedia.org/wiki/Pan_European_Game_Information), and a price.
#    - A CPU has a model code, an amout of cache levels, an amount of cores, and the frequency. (example: https://ark.intel.com/products/97185/Intel-Core-i7-7700HQ-Processor-6M-Cache-up-to-3_80-GHz)
#    - Modify the solution of the exercise above to explicitly represent the level of the cache and the size of each cache level (again refer to the link above).
#    - Represent a citizen with BSN, name, surname, address, and job. An address contains the city, street, and house number. The job contains a name, a salary, and a scale level (which is a number).
#
# _For the following exercises use GrandeOmega_
#
#
# 1. What is the next state returned by $\{ name := \text{"Mario"}, age := 24 \}[age := 25]?$
#     1. $\{ name := \text{"Mario"}, age := 26 \}$
#     - $\{ name := \text{"Stefan"}, age := 26 \}$
#     - $\{ name := \text{"Mario"}, age := 25 \}$
#     - An error
#
# - What is the result of $\{ x := 10, y := 5 \}[x]?$
#     1. $x$
#     - $y$
#     - $10$
#     - $5$
#
# - What is the result of $\{ x := 1, y := 2 \}[y]$
#     1. 2
#     - 1
#     - $\{ x := 1, y := 2 \}$
#     - y
#
# - What is the result of $\{ x := 1, y := 2 \}[y := 3]$?
#     1. 3
#     - y
#     - $\{ y := 3 \}$
#     - $\{ x := 1, y := 3 \}$
#
# - What is the result of $\{ x := \{a1 : = 3,a2 := 1\}, y := 2 \}[y : = -1]$ ?
#     1. $\{ x := -1, y := 2 \}$
#     - $\{ a1 := 3, a2 := 1, y := -1 \}$
#     - $\{ x := \{a1 : = 3,a2 := 1\}, y := -1 \}$
#     - $\{a1 : = 3,a2 := 1\}$
#
# - What is the result of $\{ x := \{a1 : = 3,a2 := 1\}, y := 2 \}[x][a1 : = 5]$ ?
#     1. $\{a1 : = 5,a2 := 1\}$
#     - $\{a1 : = 5,a2 := 1\}, y := 2 \}$
#     - $\{x := \{a1 : = 5,a2 := 1\}, y := 2\}$
#     - $\{ x:= \{a1 : = 5,a2 := 1\}\}$
#
# - What is the result of $\{x := \{y := 1\}\}[x][y]$ ?
#     1. \{x,y\}
#     - \{y := 1\}
#     - \{x := 1\}
#     - 1
#
# - What is the next state returned by $\{ x := \{a1 : = 3,a2 := 1\}, y := 2 \}[y := [x][a2]]$ ?
#     1. $\{a1 : = 3,a2 := 1\}$
#     - $\{ x := \{a1 : = 3,a2 := 1\}, y := 1 \}$
#     - the formula makes no sense.
#     - $\{x: = 2\}$
#
# - What is the result of $\{ x := \{ a1 := 2, d := \text{"How are you?"} \}, y := 5 \}[x][d]$ ?
#     1. "Fine!"
#     - $\{ a1 := 2, d := \text{"How are you?"} \}$
#     - "How are you"
#     - "How are you?"
#
# - What is the next state of $\{ x := \{ a1 := 2, d := \text{"How are you?"} \}, y := 5 \}[x][d: = 5][d]$ ?
#     1. 5
#     - "How are you?"
#     - the formula makes no sense.
#     - $\{ a1 := 2, d := 5 \}$
#
# *For the following exercises do not use GrandeOmega. Assume that, by convention, the horizontal axis points to the right and the vertical axis points to the top. Also remember that in "Turtle" programming language the state contains a variable p that stores the state of the pen.*
#
# 1. Given the state $\{ x := 5, y := -2, p := \text{"on"} \}$, where x and y represent the position of turtle, write the state trace (the representation of the state after executing each statement) of the following program and draw the picture rendered by the pen in the reference system.
#     ```
#     up 4;
#     right 1;
#     down 1;
#     done;
#     ```
#
# - Given the state $\{ x := 2, y := 1, p := \text{"on"} \}$ write the state trace of the following program and draw the picture rendered by the pen in the reference system.
#     ```
#     up 3;
#     right 5;
#     pen off;
#     down 1;
#     done;
#     ```
#
# - Given the state $\{ x := 2, y := 1, p := \text{"on"} \}$ write the state trace of the following program and draw the picture rendered by the pen in the reference system.
#    ```
#    down 3;
#    pen off;
#    right -2;
#    pen on;
#    right 3;
#    done;
#    ```
#
# - Given the state $\{ x := 0, y := 0, p := \text{"on"} \}$ write the state trace of the following program and draw the picture rendered by the pen in the reference system.
#     ```
#     pen off
#     right 5;
#     down -1;
#     pen on;
#     left -3;
#     right -4;
#     done;
#     ```
#
# - Given the state $\{ x := 5, y := -2, p := \text{"on"} \}$ write the state trace of the following program and draw the picture rendered by the pen in the reference system.
#
#     ```
#     pen on;
#     right -3;
#     up 4;
#     pen off;
#     down -2;
#     left 5;
#     up -3;
#     done;
#     ```
#
# - Given the state $\{ x := -1, y := 4, p := \text{"on"} \}$ write the state trace of the following program and draw the picture rendered by the pen in the reference system.
#     ```
#     right 3;
#     pen off;
#     up -5;
#     pen on;
#     left 4;
#     done;
#     ```
#
#
# SOLUTION OF EXERCISE 1
#
# ```
# eval (<P>,S) -> <P'>, S'
#
# { x := 5, y := -2, p := "on" }
#
# up 4;
# right 1;
# down 1;
# done
#
# eval(<up 4; right 1; down 1; done>, { x := 5, y := -2, p := "on" })
#   -> <done; right 1; down 1; done>, { x := 5, y := -2, p := "on" }[ y:= { x := 5, y := -2, p := "on" }[y] + 4 ]
#
# 	with resulting state:
# 	{ x := 5, y := -2, p := "on" }[ y:= { x := 5, y := -2, p := "on" }[y] + 4 ]
# 	{ x := 5, y := -2, p := "on" }[ y:= -2 + 4 ]
# 	{ x := 5, y := -2, p := "on" }[ y:= 2 ]
# 	{ x := 5, y := 2, p := "on" }
#
#
# eval(<done; right 1; down 1; done>, { x := 5, y := 2, p := "on" })
#   -> <right 1; down 1; done>, { x := 5, y := 2, p := "on" }
#
#
# eval(<right 1; down 1; done>, { x := 5, y := 2, p := "on" })
#   -> <done; down 1; done>, { x := 5, y := 2, p := "on" }[ x:= { x := 5, y := -2, p := "on" }[x] + 1 ]
#
# 	with resulting state:
# 	{ x := 5, y := 2, p := "on" }[ x:= { x := 5, y := -2, p := "on" }[x] + 1 ]
# 	{ x := 5, y := 2, p := "on" }[ x:= 5 + 1 ]
# 	{ x := 5, y := 2, p := "on" }[ x:= 6 ]
# 	{ x := 6, y := 2, p := "on" }
#
#
# eval(<done; down 1; done>, { x := 6, y := 2, p := "on" })
#   -> <down 1; done>, { x := 6, y := 2, p := "on" }
#
#
# eval(<down 1; done>, { x := 6, y := 2, p := "on" })
#   -> <done; done>, { x := 6, y := 2, p := "on" }[ y:= { x := 6, y := 2, p := "on" }[y] - 1 ]
#
# 	with resulting state:
# 	{ x := 6, y := 2, p := "on" }[ y:= { x := 6, y := 2, p := "on" }[y] - 1 ]
# 	{ x := 6, y := 2, p := "on" }[ y:= 2 - 1 ]
# 	{ x := 6, y := 2, p := "on" }[ y:= 1 ]
# 	{ x := 6, y := 1, p := "on" }
#
#
# eval(<done; done>, { x := 6, y := 1, p := "on" })
#   -> <done>, { x := 6, y := 1, p := "on" }
#   ```
